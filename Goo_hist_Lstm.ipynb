# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Load the dataset
df = pd.read_csv('google_stock_data_2004_2019.csv')

# %%
# Data Cleaning
# Drop unnecessary columns
df = df[['Close']]

# Check for missing values
df.isnull().sum()

# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(df)

# %%
# Prepare the dataset for LSTM
def create_dataset(data, time_step=28):
    X, Y = [], []
    for i in range(len(data) - time_step - 1):
        X.append(data[i:(i + time_step), 0])
        Y.append(data[i + time_step, 0])
    return np.array(X), np.array(Y)

time_step = 28
X, Y = create_dataset(scaled_data, time_step)

# %%
X = X.reshape(X.shape[0], X.shape[1], 1)

# %%
train_size = int(len(X) * 0.8)
test_size = len(X) - train_size
X_train, X_test = X[0:train_size], X[train_size:len(X)]
Y_train, Y_test = Y[0:train_size], Y[train_size:len(Y)]

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(time_step, 1)))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
model.fit(X_train, Y_train, batch_size=64, epochs=50)
# Out:
# Epoch 1/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - loss: 0.0233
# Epoch 2/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 2.6097e-04
# Epoch 3/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 1.3749e-04
# Epoch 4/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 1.6062e-04
# Epoch 5/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 1.3265e-04
# Epoch 6/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1.3695e-04
# Epoch 7/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 1.2048e-04
# Epoch 8/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 1.2854e-04
# Epoch 9/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - loss: 1.2245e-04
# Epoch 10/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 1.1406e-04
# Epoch 11/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 1.1898e-04
# Epoch 12/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 1.1337e-04
# Epoch 13/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - loss: 1.0051e-04
# Epoch 14/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 1.0497e-04
# Epoch 15/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 9.8969e-05
# Epoch 16/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 1.1996e-04
# Epoch 17/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - loss: 1.0481e-04
# Epoch 18/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - loss: 9.9586e-05
# Epoch 19/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 1.0083e-04
# Epoch 20/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 9.5201e-05
# Epoch 21/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 1.0496e-04
# Epoch 22/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 8.5119e-05
# Epoch 23/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 9.0459e-05
# Epoch 24/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 1.0199e-04
# Epoch 25/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 8.4753e-05
# Epoch 26/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 8.7053e-05
# Epoch 27/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 8.1829e-05
# Epoch 28/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 8.5186e-05
# Epoch 29/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 8.5051e-05
# Epoch 30/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 8.8452e-05
# Epoch 31/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 7.2075e-05
# Epoch 32/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 7.9962e-05
# Epoch 33/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - loss: 8.0758e-05
# Epoch 34/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 8.9094e-05
# Epoch 35/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 8.3061e-05
# Epoch 36/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 7.7435e-05
# Epoch 37/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 6.9839e-05
# Epoch 38/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 7.5572e-05
# Epoch 39/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 8.7156e-05
# Epoch 40/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 6.2532e-05
# Epoch 41/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 6.3632e-05
# Epoch 42/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 6.5185e-05
# Epoch 43/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 6.7117e-05
# Epoch 44/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 6.0955e-05
# Epoch 45/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 7.3860e-05
# Epoch 46/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 6.4420e-05
# Epoch 47/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 5.9697e-05
# Epoch 48/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 6.0811e-05
# Epoch 49/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 5.7029e-05
# Epoch 50/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 5.2886e-05

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
# Out:
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step

# %%
train_predict = scaler.inverse_transform(train_predict)
Y_train_inv = scaler.inverse_transform([Y_train])
test_predict = scaler.inverse_transform(test_predict)
Y_test_inv = scaler.inverse_transform([Y_test])

# %%
mse = mean_squared_error(Y_test_inv[0], test_predict[:, 0])
mae = mean_absolute_error(Y_test_inv[0], test_predict[:, 0])
r2 = r2_score(Y_test_inv[0], test_predict[:, 0])

print('MSE:',mse)
print('MAE',mae)
print('R2',r2)
# Out:
# MSE: 1.0744151044148957
# MAE 0.7679486623896916
# R2 0.9760240748129086

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.index[time_step:train_size + time_step], Y_train_inv[0], label='Actual Train Price', color='blue')
plt.plot(df.index[train_size + time_step + 1:len(df)], Y_test_inv[0], label='Actual Test Price', color='green')
plt.plot(df.index[time_step:train_size + time_step], train_predict[:, 0], label='Predicted Train Price', color='red')
plt.plot(df.index[train_size + time_step + 1:len(df)], test_predict[:, 0], label='Predicted Test Price', color='orange')
plt.title('Apple Stock Price Prediction vs Actual Price')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.show()
